# %%
pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.1.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.20.0 in /opt/anaconda3/lib/python3.8/site-packages (from sodapy) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests>=2.20.0->sodapy) (1.26.4)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#add dependencies
import requests
import json
import pandas as pd
from sodapy import Socrata

# %%
client = Socrata("data.cdc.gov", None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("8xkx-amqh")

# %%
results_df = pd.DataFrame.from_records(results)

# %%
results_df.head()
# Out:
#                       date   fips mmwr_week       recip_county recip_state  \
# 0  2021-10-24T00:00:00.000  48003        43     Andrews County          TX
# 1  2021-10-24T00:00:00.000  18053        43       Grant County          IN
# 2  2021-10-24T00:00:00.000  17135        43  Montgomery County          IL
# 3  2021-10-24T00:00:00.000  21205        43       Rowan County          KY
# 4  2021-10-24T00:00:00.000  20047        43     Edwards County          KS
#
#   series_complete_pop_pct series_complete_yes series_complete_12plus  \
# 0                    39.2                7329                   7329
# 1                    38.4               25264                  25263
# 2                    40.6               11538                  11533
# 3                    47.6               11634                  11634
# 4                    43.3                1211                   1211
#
#   series_complete_12pluspop series_complete_18plus  ... svi_ctgy  \
# 0                      49.5                   6815  ...        B
# 1                      44.4                  24383  ...        C
# 2                      46.7                  11032  ...        B
# 3                      54.8                  10985  ...        D
# 4                      50.8                   1155  ...        B
#
#   series_complete_pop_pct_svi series_complete_12pluspop_pct_svi  \
# 0                           6                                 7
# 1                          10                                11
# 2                           7                                 7
# 3                          15                                16
# 4                           7                                 8
#
#   series_complete_18pluspop_pct_svi series_complete_65pluspop_pct_svi  \
# 0                                 8                                 8
# 1                                11                                12
# 2                                 7                                 8
# 3                                16                                16
# 4                                 8                                 8
#
#   metro_status series_complete_pop_pct_ur_equity  \
# 0    Non-metro                                 6
# 1    Non-metro                                 6
# 2    Non-metro                                 7
# 3    Non-metro                                 7
# 4    Non-metro                                 7
#
#   series_complete_12pluspop_pct_ur_equity  \
# 0                                       7
# 1                                       7
# 2                                       7
# 3                                       8
# 4                                       8
#
#   series_complete_18pluspop_pct_ur_equity  \
# 0                                       8
# 1                                       7
# 2                                       7
# 3                                       8
# 4                                       8
#
#   series_complete_65pluspop_pct_ur_equity
# 0                                       8
# 1                                       8
# 2                                       8
# 3                                       8
# 4                                       8
#
# [5 rows x 32 columns]

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 32 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   date                                     1000 non-null   object
#  1   fips                                     1000 non-null   object
#  2   mmwr_week                                1000 non-null   object
#  3   recip_county                             1000 non-null   object
#  4   recip_state                              1000 non-null   object
#  5   series_complete_pop_pct                  1000 non-null   object
#  6   series_complete_yes                      1000 non-null   object
#  7   series_complete_12plus                   989 non-null    object
#  8   series_complete_12pluspop                989 non-null    object
#  9   series_complete_18plus                   1000 non-null   object
#  10  series_complete_18pluspop                1000 non-null   object
#  11  series_complete_65plus                   1000 non-null   object
#  12  series_complete_65pluspop                1000 non-null   object
#  13  completeness_pct                         1000 non-null   object
#  14  administered_dose1_recip                 963 non-null    object
#  15  administered_dose1_pop_pct               1000 non-null   object
#  16  administered_dose1_recip_12plus          938 non-null    object
#  17  administered_dose1_recip_12pluspop_pct   989 non-null    object
#  18  administered_dose1_recip_18plus          949 non-null    object
#  19  administered_dose1_recip_18pluspop_pct   1000 non-null   object
#  20  administered_dose1_recip_65plus          949 non-null    object
#  21  administered_dose1_recip_65pluspop_pct   1000 non-null   object
#  22  svi_ctgy                                 981 non-null    object
#  23  series_complete_pop_pct_svi              976 non-null    object
#  24  series_complete_12pluspop_pct_svi        965 non-null    object
#  25  series_complete_18pluspop_pct_svi        976 non-null    object
#  26  series_complete_65pluspop_pct_svi        976 non-null    object
#  27  metro_status                             981 non-null    object
#  28  series_complete_pop_pct_ur_equity        976 non-null    object
#  29  series_complete_12pluspop_pct_ur_equity  965 non-null    object
#  30  series_complete_18pluspop_pct_ur_equity  976 non-null    object
#  31  series_complete_65pluspop_pct_ur_equity  976 non-null    object
# dtypes: object(32)
# memory usage: 250.1+ KB
